# %% [markdown]
# # Regressão Linear

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Regressão Linear Simples

# %%
temperaturas = np.array(range(0, 40, 2))
temperaturas = temperaturas.reshape(-1, 1)
vendas = [65, 58, 46, 45, 44, 42, 40, 40, 36, 38, 38, 28, 30, 22, 27, 25, 25, 20, 15, 5]

plt.plot(temperaturas, vendas, 'o')
plt.xlabel("Temperatura")
plt.ylabel("Vendas")
plt.show()

# %%
inclinacao = -2
interceptacao = 65

# %%
plt.plot(temperaturas, vendas, 'o')
plt.xlabel("Temperatura")
plt.ylabel("Vendas")

y = [interceptacao + inclinacao*x for x in temperaturas]
#altere os valores de inclinação e interceptação para os valores que você acha que ajustem melhor a reta aos dados.

plt.plot(temperaturas,y)
plt.show()

# %% [markdown]
# Quando pensamos em como podemos atribuir uma inclinação e uma interceptação para ajustar um conjunto de pontos, temos que definir qual é o melhor ajuste .
#
# Para cada ponto de dados, calculamos o **erro** , um número que mede o quão ruim foi a previsão do modelo.

# %% [markdown]
# Podemos pensar no erro como a distância quadrada do ponto à linha. Fazemos a distância ao quadrado (em vez de apenas a distância) para que os pontos acima e abaixo da linha contribuam para a perda total da mesma maneira:

# %%
Image('erro.png')

# %%
erro = 0
for i,j in zip(y,vendas):
    erro+=(i-j)**2
print(erro)
# Out:
# [3365]

# %%
regressaoLinear = LinearRegression()

# %%
# Treinando o modelo
regressaoLinear.fit(temperaturas,vendas)
# Out:
# LinearRegression()

# %%
previsao_vendas = regressaoLinear.predict(temperaturas)
plt.plot(temperaturas, vendas, 'o')
plt.plot(temperaturas,previsao_vendas)
plt.show()

# %%
#Prevendo o número de casacos vendidos
print("%.2f" %regressaoLinear.predict([[25]]))
# Out:
# 27.54

# %%
regressaoLinear.coef_
# Out:
# array([-1.15225564])

# %%
regressaoLinear.intercept_
# Out:
# 56.34285714285715

# %% [markdown]
# ### Coficiente de determinação (R²)

# %%
Image('r2.png')

# %% [markdown]
# **ŷ representa o valor predito, y_barra representa o valor médio das amostras e yi representa o valor real.**

# %%
Image('r2_gráficos.png')

# %% [markdown]
# #### Na imagem acima, podemos ver que se o modelo (reta) não se distancia muito dos dados, temos um valor de R-Quadrado alto (gráfico 1), em contraste com o gráfico 2.

# %%
# em metrics, temos quase todas as metricas geralmente utilizadas
from sklearn.metrics import r2_score 

R2 = r2_score(vendas,previsao_vendas)
print(R2)
# Out:
# 0.9114088011031334

# %% [markdown]
# ## Regressão Linear Múltipla

# %%
import pandas as pd

# %%
moradias = pd.read_csv('moradias.csv')
moradias.head()
# Out:
#    rental_id   rent  bedrooms  bathrooms  size_sqft  min_to_subway  floor  \
# 0       1545   2550       0.0          1        480              9    2.0
# 1       2472  11500       2.0          2       2000              4    1.0
# 2       2919   4500       1.0          1        916              2   51.0
# 3       2790   4795       1.0          1        975              3    8.0
# 4       3946  17500       2.0          2       4800              3    4.0
#
#    building_age_yrs  no_fee  has_roofdeck  has_washer_dryer  has_doorman  \
# 0                17       1             1                 0            0
# 1                96       0             0                 0            0
# 2                29       0             1                 0            1
# 3                31       0             0                 0            1
# 4               136       0             0                 0            1
#
#    has_elevator  has_dishwasher  has_patio  has_gym       neighborhood  \
# 0             1               1          0        1    Upper East Side
# 1             0               0          0        0  Greenwich Village
# 2             1               1          0        0            Midtown
# 3             1               1          0        1  Greenwich Village
# 4             1               1          0        1               Soho
#
#      borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
moradias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3539 entries, 0 to 3538
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rental_id         3539 non-null   int64
#  1   rent              3539 non-null   int64
#  2   bedrooms          3539 non-null   float64
#  3   bathrooms         3539 non-null   int64
#  4   size_sqft         3539 non-null   int64
#  5   min_to_subway     3539 non-null   int64
#  6   floor             3539 non-null   float64
#  7   building_age_yrs  3539 non-null   int64
#  8   no_fee            3539 non-null   int64
#  9   has_roofdeck      3539 non-null   int64
#  10  has_washer_dryer  3539 non-null   int64
#  11  has_doorman       3539 non-null   int64
#  12  has_elevator      3539 non-null   int64
#  13  has_dishwasher    3539 non-null   int64
#  14  has_patio         3539 non-null   int64
#  15  has_gym           3539 non-null   int64
#  16  neighborhood      3539 non-null   object
#  17  borough           3539 non-null   object
# dtypes: float64(2), int64(14), object(2)
# memory usage: 497.8+ KB

# %%
x = moradias[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]
y = moradias[['rent']]

# %%
#Dividindo o conjunto entre treinamento e teste
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 14)
# (708, 14)
# (2831, 1)
# (708, 1)

# %%
regressaoMultipla = LinearRegression()
regressaoMultipla.fit(x_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
dadosImovel = [[1, 1, 620, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]

previsao_aluguel = regressaoMultipla.predict(dadosImovel)

print("Previsão preço do Aluguel: $%.2f" % previsao_aluguel)
# Out:
# Previsão preço do Aluguel: $2337.60

# %%
y_previsto = regressaoMultipla.predict(x_test.values)

# %%
plt.scatter(y_test, y_previsto)

plt.xlabel("Preços: $Y_i$")
plt.ylabel("Previsão Preços: $\hat{Y}_i$")
plt.title("Aluguel Real vs Aluguel Previsto")

plt.show()

# %%
#Coficiente de determinação (R²)
R2 = r2_score(y_test,y_previsto)
print(R2)
# Out:
# 0.7830869546936723

# %%
corr = moradias.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_afae7_row0_col0, #T_afae7_row1_col1, #T_afae7_row2_col2, #T_afae7_row3_col3, #T_afae7_row4_col4, #T_afae7_row5_col5, #T_afae7_row6_col6, #T_afae7_row7_col7, #T_afae7_row8_col8, #T_afae7_row9_col9, #T_afae7_row10_col10, #T_afae7_row11_col11, #T_afae7_row12_col12, #T_afae7_row13_col13, #T_afae7_row14_col14, #T_afae7_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col1, #T_afae7_row0_col3, #T_afae7_row0_col10, #T_afae7_row1_col0, #T_afae7_row6_col7, #T_afae7_row7_col5, #T_afae7_row7_col6, #T_afae7_row7_col8, #T_afae7_row7_col14, #T_afae7_row8_col2, #T_afae7_row8_col4, #T_afae7_row8_col9, #T_afae7_row8_col10, #T_afae7_row8_col11, #T_afae7_row8_col12, #T_afae7_row8_col13, #T_afae7_row8_col14, #T_afae7_row8_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col2, #T_afae7_row4_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col4, #T_afae7_row8_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col5, #T_afae7_row5_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col6, #T_afae7_row2_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_afae7_row0_col8, #T_afae7_row6_col11, #T_afae7_row12_col7, #T_afae7_row15_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_afae7_row0_col9, #T_afae7_row4_col8, #T_afae7_row12_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col11, #T_afae7_row3_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col12, #T_afae7_row2_col15, #T_afae7_row3_col14, #T_afae7_row5_col15, #T_afae7_row7_col12, #T_afae7_row15_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col13, #T_afae7_row0_col14, #T_afae7_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_afae7_row0_col15 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_afae7_row1_col3, #T_afae7_row4_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col4 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col5, #T_afae7_row1_col7, #T_afae7_row1_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col6 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_afae7_row1_col8, #T_afae7_row2_col8, #T_afae7_row9_col0, #T_afae7_row10_col2, #T_afae7_row15_col0, #T_afae7_row15_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col9, #T_afae7_row1_col10, #T_afae7_row3_col15, #T_afae7_row4_col13, #T_afae7_row4_col15, #T_afae7_row8_col7, #T_afae7_row12_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col11, #T_afae7_row10_col14, #T_afae7_row11_col14 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col13, #T_afae7_row10_col3, #T_afae7_row10_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col14, #T_afae7_row2_col10, #T_afae7_row2_col13, #T_afae7_row6_col13, #T_afae7_row11_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_afae7_row1_col15, #T_afae7_row5_col0, #T_afae7_row7_col2, #T_afae7_row15_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_afae7_row2_col3, #T_afae7_row3_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_afae7_row2_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col6, #T_afae7_row6_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_afae7_row2_col7, #T_afae7_row10_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_afae7_row2_col9, #T_afae7_row3_col10, #T_afae7_row13_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col11, #T_afae7_row5_col12, #T_afae7_row6_col9, #T_afae7_row9_col5, #T_afae7_row14_col3, #T_afae7_row14_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col12, #T_afae7_row7_col4, #T_afae7_row13_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_afae7_row2_col14, #T_afae7_row10_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col6, #T_afae7_row10_col9, #T_afae7_row11_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_afae7_row3_col7, #T_afae7_row6_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col8, #T_afae7_row6_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col9, #T_afae7_row4_col10, #T_afae7_row6_col10, #T_afae7_row6_col14, #T_afae7_row9_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col11, #T_afae7_row9_col14, #T_afae7_row10_col1, #T_afae7_row12_col1, #T_afae7_row13_col1, #T_afae7_row15_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_afae7_row3_col12, #T_afae7_row5_col4, #T_afae7_row10_col4, #T_afae7_row12_col4, #T_afae7_row14_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_afae7_row4_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_afae7_row4_col9, #T_afae7_row11_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col11, #T_afae7_row5_col3, #T_afae7_row12_col14 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col12, #T_afae7_row8_col0, #T_afae7_row13_col14 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_afae7_row4_col14, #T_afae7_row5_col9, #T_afae7_row5_col10, #T_afae7_row11_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_afae7_row5_col1, #T_afae7_row6_col15, #T_afae7_row9_col1, #T_afae7_row15_col4, #T_afae7_row15_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_afae7_row5_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_afae7_row5_col7, #T_afae7_row5_col11, #T_afae7_row9_col4, #T_afae7_row11_col1, #T_afae7_row11_col4, #T_afae7_row11_col5, #T_afae7_row13_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_afae7_row5_col8, #T_afae7_row11_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_afae7_row5_col13 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_afae7_row5_col14, #T_afae7_row7_col9, #T_afae7_row7_col13, #T_afae7_row12_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_afae7_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_afae7_row6_col5, #T_afae7_row8_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_afae7_row6_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_afae7_row6_col12, #T_afae7_row14_col9, #T_afae7_row14_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col0, #T_afae7_row14_col1, #T_afae7_row14_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col10, #T_afae7_row8_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col11, #T_afae7_row9_col3, #T_afae7_row13_col8, #T_afae7_row14_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_afae7_row7_col15, #T_afae7_row11_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_afae7_row8_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_afae7_row9_col2, #T_afae7_row13_col2, #T_afae7_row14_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_afae7_row9_col6, #T_afae7_row14_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_afae7_row9_col7 {
#   backgrou

# %%
x = moradias[['bedrooms','bathrooms','size_sqft']]
y = moradias[['rent']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 3)
# (708, 3)
# (2831, 1)
# (708, 1)

# %%
regressaoMultipla = LinearRegression()
regressaoMultipla.fit(x_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
y_previsto = regressaoMultipla.predict(x_test.values)

# %%
#Coficiente de determinação (R²)
R2 = r2_score(y_test,y_previsto)
print(R2)
# Out:
# 0.7334576543191733

# %%
dadosImovel = [[4,1,3000]]

preco_aluguel = regressaoMultipla.predict(dadosImovel)

print("Previsão Aluguel: $%.2f" % preco_aluguel)
# Out:
# Previsão Aluguel: $14050.72

# %%
regressaoMultipla.coef_
# Out:
# array([[-402.79297574, 1310.56212223,    5.06646462]])

# %% [markdown]
# #### Os coeficientes são úteis para determinar qual variável independente tem mais peso. Por exemplo, um coeficiente de 1369.30 impactará o aluguel mais do que um coeficiente de -415.13, com o primeiro impactando os preços positivamente e o último negativamente.

# %%
y_previsto = regressaoMultipla.predict(x_test.values)

# %%
plt.scatter(y_test, y_previsto, c = 'b',  s = 50, alpha = 0.5)

plt.xlabel("Preços: $Y_i$")
plt.ylabel("Previsão Preços: $\hat{Y}_i$")
plt.title("Aluguel Real vs Aluguel Previsto")

plt.show()

# %%
plt.scatter(y_previsto, y_previsto - y_test, c = 'b',  s = 50, alpha = 0.5)
plt.axhline(y=0, color='r', linestyle='-')
plt.ylabel("Resíduo")
plt.title("Gráfico Residual ")
plt.show()

# %% [markdown]
# ## Outras métricas de avaliação do modelo

# %% [markdown]
# ### Erro Quadrático Médio (MSE)

# %%
Image('mse.png')

# %% [markdown]
# O MSE consiste na média do erro das previsões ao quadrado. Em outras palavras, pega-se a diferença entre o valor predito pelo modelo e o valor real, eleva-se o resultado ao quadrado, faz-se a mesma coisa com todos os outros pontos, soma-os, e dividi-se pelo número de elementos preditos. Quanto maior esse número, pior o modelo.

# %% [markdown]
# #### Vantagens e Desvantagens

# %% [markdown]
# Uma vez que essa métrica eleva o erro ao quadrado, predições muito distantes do real aumentam o valor da medida muito facilmente, o que a torna uma métrica de avaliação excelente para problemas nos quais grandes erros não são tolerados, como é o caso de exames médicos e projeções de preços.
#
# Entretanto, um ponto negativo do uso dessa métrica é sua falta de interpretabilidade direta, uma vez que, para a predição de valores de unidade u, a unidade do MSE seria u²

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test,y_previsto)
print("%.2f" %MSE)
# Out:
# 2593720.21

# %% [markdown]
# ### Raiz do erro quadrático médio (RMSE)

# %% [markdown]
# Tendo em vista essa diferença de unidades, o RMSE entra como uma forma de melhorar a interpretabilidade da métrica, acertando a unidade. Entretanto, essa medida, assim como o MSE, penaliza predições muito distantes da real.

# %%
Image('rmse.png')

# %%
RMSE = mean_squared_error(y_test,y_previsto,squared=False) 
# argumento 'squared' dado como false nos da o RMSE

# ou podemos simplesmente tirar a raiz quadrada do MSE
RMSE = MSE**0.5

print("%.2f" %RMSE)
# Out:
# 1610.50

# %% [markdown]
# ### Erro Percentual Absoluto Médio (MAPE)

# %% [markdown]
# Em contraste com as métricas anteriores, essa medida exprime uma porcentagem, obtida através da divisão da diferença entre predito (ŷ) e real pelo valor real (y).
#
# Assim como o MSE e o RMSE, quanto menor o valor, mais preciso seria o modelo de regressão.

# %%
Image('mape.png')

# %% [markdown]
# #### Por se tratar de uma porcentagem, essa métrica torna-se extremamente intuitiva, tanto para a interpretação do programador, quanto para a comunicação de resultados com pessoas sem conhecimento técnico. Por exemplo, ter um MAPE=12% significa que, em média, nosso modelo faz previsões que erram por 12% do valor real.

# %%
MAPE = np.mean(np.abs((y_test - y_previsto) / y_test), axis=0) * 100
print("Valor do MAPE %.2f" % MAPE + "%")
# Out:
# Valor do MAPE 20.94%
